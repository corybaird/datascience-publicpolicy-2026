# %% [markdown]
# # Homework 1: Data Reading & Manipulation
#
# In this homework, you will practice:
# 1. Reading data from CSV files and APIs
# 2. Data manipulation techniques covered in Week 2

# %% [markdown]
# # Section 1: Reading Data

# %% [markdown]
# ## 1.1 Reading CSV Files
#
# ##### IMPORTANT: We will read data from the `data/hw/` folder so you need to remember to go back two folders to access data

# %%
#IMPORT PANDAS TOOLS
import pandas as pd

# %% [markdown]
# ### 1.1.1 GDP and Democracy Data
#
# Load the `democracy_gdp.csv` file.

# %%
democracy_gdp_filepath = "../../data/hw/democracy_gdp.csv"
democracy_gdp = pd.read_csv(democracy_gdp_filepath)
democracy_gdp.head(10)
# Out:
#   country  year  v2x_frassoc_thick  NGDPDPC  NGDP_RPCH  v2x_pubcorr  \
# 0     AFG  1990              0.063      NaN        NaN        0.556
# 1     AFG  1991              0.068      NaN        NaN        0.556
# 2     AFG  1992              0.134      NaN        NaN        0.645
# 3     AFG  1993              0.159      NaN        NaN        0.843
# 4     AFG  1994              0.159      NaN        NaN        0.843
# 5     AFG  1995              0.159      NaN        NaN        0.843
# 6     AFG  1996              0.062      NaN        NaN        0.745
# 7     AFG  1997              0.038      NaN        NaN        0.707
# 8     AFG  1998              0.038      NaN        NaN        0.707
# 9     AFG  1999              0.038      NaN        NaN        0.707
#
#    v2xnp_regcorr  v2xel_frefair  v2x_freexp  v2elembcap
# 0          0.538          0.069       0.085       -1.65
# 1          0.538          0.069       0.074       -1.65
# 2          0.736          0.028       0.071       -1.65
# 3          0.909          0.000       0.069       -1.65
# 4          0.909          0.000       0.069       -1.65
# 5          0.912          0.000       0.069       -1.65
# 6          0.906          0.000       0.029       -1.65
# 7          0.806          0.000       0.020       -1.65
# 8          0.806          0.000       0.020       -1.65
# 9          0.806          0.000       0.020       -1.65

# %% [markdown]
# ### 1.1.2 Green house gas (GHG) Emissions Data
#
# Load the `ghg.csv` file.

# %%
ghg_file_path = "../../data/hw/ghg.csv"
ghg = pd.read_csv(ghg_file_path)
ghg.tail(10)
# Out:
#             Country  year     emissions
# 11438  GLOBAL TOTAL  2014  48930.176837
# 11439  GLOBAL TOTAL  2015  48808.767176
# 11440  GLOBAL TOTAL  2016  49058.441256
# 11441  GLOBAL TOTAL  2017  49878.733809
# 11442  GLOBAL TOTAL  2018  51026.627449
# 11443  GLOBAL TOTAL  2019  51278.347920
# 11444  GLOBAL TOTAL  2020  49327.538885
# 11445  GLOBAL TOTAL  2021  51568.250032
# 11446  GLOBAL TOTAL  2022  51968.471601
# 11447  GLOBAL TOTAL  2023  52962.900859

# %% [markdown]
# ## 1.2 Reading Data from an API
#
# YOU MUST RUN THE NEXT CELL TO DOWNLOAD GDP AND POPULATION DATA

# %%
import requests
import io

def download_worldbank(indicator, countries, date_start, date_end):
    url_base = 'https://api.worldbank.org/v2/'
    country_codes = ';'.join(countries)
    url = f'{url_base}country/{country_codes}/indicator/{indicator}?date={date_start}:{date_end}&per_page=30000'
    response = requests.get(url)
    df = pd.read_xml(io.BytesIO(response.content))
    return df

# %% [markdown]
# ### 1.2.1 Download GDP Data (1990-2026)
#
# Download GDP per capita data for a different set of countries than those in the CSV files.

# %%
gdp_data = download_worldbank(
    indicator='NY.GDP.PCAP.CD',
    date_start= 1990,
    date_end= 2026,
    countries= [
        'ESP',
        'FRA',
        'DEU',
        'ITA',
    ]
)
gdp_data
# Out:
#                         indicator  country countryiso3code  date  \
# 0    GDP per capita (current US$)  Germany             DEU  2025
# 1    GDP per capita (current US$)  Germany             DEU  2024
# 2    GDP per capita (current US$)  Germany             DEU  2023
# 3    GDP per capita (current US$)  Germany             DEU  2022
# 4    GDP per capita (current US$)  Germany             DEU  2021
# ..                            ...      ...             ...   ...
# 139  GDP per capita (current US$)    Italy             ITA  1994
# 140  GDP per capita (current US$)    Italy             ITA  1993
# 141  GDP per capita (current US$)    Italy             ITA  1992
# 142  GDP per capita (current US$)    Italy             ITA  1991
# 143  GDP per capita (current US$)    Italy             ITA  1990
#
#             value  unit  obs_status  decimal
# 0             NaN   NaN         NaN        1
# 1    56103.732318   NaN         NaN        1
# 2    54776.766824   NaN         NaN        1
# 3    50506.517964   NaN         NaN        1
# 4    52349.245999   NaN         NaN        1
# ..            ...   ...         ...      ...
# 139  19382.200215   NaN         NaN        1
# 140  18781.952943   NaN         NaN        1
# 141  23297.046033   NaN         NaN        1
# 142  22007.135096   NaN         NaN        1
# 143  20873.783409   NaN         NaN        1
#
# [144 rows x 8 columns]

# %% [markdown]
# ### 1.2.2 Download Population Data (1990-2026)
#
# Download population data for the same countries.

# %%
population_indicator = 'SP.POP.TOTL'

country_list = [
    "ESP",  
    "FRA",  
    "DEU",  
    "ITA",  
]

pop_data = download_worldbank(
    indicator=population_indicator,
    countries=country_list,
    date_start=1990,
    date_end=2026
)
pop_data.tail(3)
pop_data
# Out:
#              indicator  country countryiso3code  date       value  unit  \
# 0    Population, total  Germany             DEU  2025         NaN   NaN
# 1    Population, total  Germany             DEU  2024  83516593.0   NaN
# 2    Population, total  Germany             DEU  2023  83287273.0   NaN
# 3    Population, total  Germany             DEU  2022  83177813.0   NaN
# 4    Population, total  Germany             DEU  2021  83196078.0   NaN
# ..                 ...      ...             ...   ...         ...   ...
# 139  Population, total    Italy             ITA  1994  56843400.0   NaN
# 140  Population, total    Italy             ITA  1993  56831821.0   NaN
# 141  Population, total    Italy             ITA  1992  56797087.0   NaN
# 142  Population, total    Italy             ITA  1991  56758521.0   NaN
# 143  Population, total    Italy             ITA  1990  56719240.0   NaN
#
#      obs_status  decimal
# 0           NaN        0
# 1           NaN        0
# 2           NaN        0
# 3           NaN        0
# 4           NaN        0
# ..          ...      ...
# 139         NaN        0
# 140         NaN        0
# 141         NaN        0
# 142         NaN        0
# 143         NaN        0
#
# [144 rows x 8 columns]

# %% [markdown]
# # Section 2: Data Manipulation
#
# Now let's practice the data manipulation techniques from Week 2.

# %% [markdown]
# ## 2.1 Select Columns
#
# Select specific columns from the democracy_gdp dataset.

# %%
gdp_data[['country','date','value']]
# Out:
#      country  date         value
# 0    Germany  2025           NaN
# 1    Germany  2024  56103.732318
# 2    Germany  2023  54776.766824
# 3    Germany  2022  50506.517964
# 4    Germany  2021  52349.245999
# ..       ...   ...           ...
# 139    Italy  1994  19382.200215
# 140    Italy  1993  18781.952943
# 141    Italy  1992  23297.046033
# 142    Italy  1991  22007.135096
# 143    Italy  1990  20873.783409
#
# [144 rows x 3 columns]

# %% [markdown]
# ## 2.2 Filter Rows
#
# Filter rows based on conditions.

# %%
# Show unique values in a column
gdp_data.country.unique()
# Out:
# array(['Germany', 'Spain', 'France', 'Italy'], dtype=object)

# %%
gdp_data.date.unique()
# Out:
# array([2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015,
#        2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004,
#        2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993,
#        1992, 1991, 1990])

# %%
gdp_data.countryiso3code.unique()
# Out:
# array(['DEU', 'ESP', 'FRA', 'ITA'], dtype=object)

# %%
# Filter using query

pop_data.query('countryiso3code == "ESP"')
# Out:
#             indicator country countryiso3code  date       value  unit  \
# 36  Population, total   Spain             ESP  2025         NaN   NaN
# 37  Population, total   Spain             ESP  2024  48848840.0   NaN
# 38  Population, total   Spain             ESP  2023  48352528.0   NaN
# 39  Population, total   Spain             ESP  2022  47786102.0   NaN
# 40  Population, total   Spain             ESP  2021  47443821.0   NaN
# 41  Population, total   Spain             ESP  2020  47359424.0   NaN
# 42  Population, total   Spain             ESP  2019  47118501.0   NaN
# 43  Population, total   Spain             ESP  2018  46782011.0   NaN
# 44  Population, total   Spain             ESP  2017  46571232.0   NaN
# 45  Population, total   Spain             ESP  2016  46458139.0   NaN
# 46  Population, total   Spain             ESP  2015  46422303.0   NaN
# 47  Population, total   Spain             ESP  2014  46460733.0   NaN
# 48  Population, total   Spain             ESP  2013  46604197.0   NaN
# 49  Population, total   Spain             ESP  2012  46773055.0   NaN
# 50  Population, total   Spain             ESP  2011  46742697.0   NaN
# 51  Population, total   Spain             ESP  2010  46576897.0   NaN
# 52  Population, total   Spain             ESP  2009  46362946.0   NaN
# 53  Population, total   Spain             ESP  2008  45954106.0   NaN
# 54  Population, total   Spain             ESP  2007  45226803.0   NaN
# 55  Population, total   Spain             ESP  2006  44397319.0   NaN
# 56  Population, total   Spain             ESP  2005  43653155.0   NaN
# 57  Population, total   Spain             ESP  2004  42921895.0   NaN
# 58  Population, total   Spain             ESP  2003  42187645.0   NaN
# 59  Population, total   Spain             ESP  2002  41431558.0   NaN
# 60  Population, total   Spain             ESP  2001  40850412.0   NaN
# 61  Population, total   Spain             ESP  2000  40567864.0   NaN
# 62  Population, total   Spain             ESP  1999  40386875.0   NaN
# 63  Population, total   Spain             ESP  1998  40223509.0   NaN
# 64  Population, total   Spain             ESP  1997  40057389.0   NaN
# 65  Population, total   Spain             ESP  1996  39889852.0   NaN
# 66  Population, total   Spain             ESP  1995  39724050.0   NaN
# 67  Population, total   Spain             ESP  1994  39549108.0   NaN
# 68  Population, total   Spain             ESP  1993  39361262.0   NaN
# 69  Population, total   Spain             ESP  1992  39157685.0   NaN
# 70  Population, total   Spain             ESP  1991  38966376.0   NaN
# 71  Population, total   Spain             ESP  1990  38867322.0   NaN
#
#     obs_status  decimal
# 36         NaN        0
# 37         NaN        0
# 38         NaN        0
# 39         NaN        0
# 40         NaN        0
# 41         NaN        0
# 42         NaN        0
# 43         NaN        0
# 44         NaN        0
# 45         NaN        0
# 46         NaN        0
# 47         NaN        0
# 48         NaN        0
# 49         NaN        0
# 50         NaN        0
# 51         NaN        0
# 52         NaN        0
# 53         NaN        0
# 54         NaN        0
# 55         NaN        0
# 56         NaN        0
# 57         NaN        0
# 58         NaN        0
# 59         NaN        0
# 60         NaN        0
# 61         NaN        0
# 62         NaN        0
# 63         NaN        0
# 64         NaN        0
# 65         NaN        0
# 66         NaN        0
# 67         NaN        0
# 68         NaN        0
# 69         NaN        0
# 70         NaN        0
# 71         NaN        0

# %% [markdown]
# ## 2.3 Multiple Conditions
#
# Filter using multiple conditions.

# %%
# Filter with multiple conditions

pop_data.query('country == "Spain" & date >= 2000')
# Out:
#             indicator country countryiso3code  date       value  unit  \
# 36  Population, total   Spain             ESP  2025         NaN   NaN
# 37  Population, total   Spain             ESP  2024  48848840.0   NaN
# 38  Population, total   Spain             ESP  2023  48352528.0   NaN
# 39  Population, total   Spain             ESP  2022  47786102.0   NaN
# 40  Population, total   Spain             ESP  2021  47443821.0   NaN
# 41  Population, total   Spain             ESP  2020  47359424.0   NaN
# 42  Population, total   Spain             ESP  2019  47118501.0   NaN
# 43  Population, total   Spain             ESP  2018  46782011.0   NaN
# 44  Population, total   Spain             ESP  2017  46571232.0   NaN
# 45  Population, total   Spain             ESP  2016  46458139.0   NaN
# 46  Population, total   Spain             ESP  2015  46422303.0   NaN
# 47  Population, total   Spain             ESP  2014  46460733.0   NaN
# 48  Population, total   Spain             ESP  2013  46604197.0   NaN
# 49  Population, total   Spain             ESP  2012  46773055.0   NaN
# 50  Population, total   Spain             ESP  2011  46742697.0   NaN
# 51  Population, total   Spain             ESP  2010  46576897.0   NaN
# 52  Population, total   Spain             ESP  2009  46362946.0   NaN
# 53  Population, total   Spain             ESP  2008  45954106.0   NaN
# 54  Population, total   Spain             ESP  2007  45226803.0   NaN
# 55  Population, total   Spain             ESP  2006  44397319.0   NaN
# 56  Population, total   Spain             ESP  2005  43653155.0   NaN
# 57  Population, total   Spain             ESP  2004  42921895.0   NaN
# 58  Population, total   Spain             ESP  2003  42187645.0   NaN
# 59  Population, total   Spain             ESP  2002  41431558.0   NaN
# 60  Population, total   Spain             ESP  2001  40850412.0   NaN
# 61  Population, total   Spain             ESP  2000  40567864.0   NaN
#
#     obs_status  decimal
# 36         NaN        0
# 37         NaN        0
# 38         NaN        0
# 39         NaN        0
# 40         NaN        0
# 41         NaN        0
# 42         NaN        0
# 43         NaN        0
# 44         NaN        0
# 45         NaN        0
# 46         NaN        0
# 47         NaN        0
# 48         NaN        0
# 49         NaN        0
# 50         NaN        0
# 51         NaN        0
# 52         NaN        0
# 53         NaN        0
# 54         NaN        0
# 55         NaN        0
# 56         NaN        0
# 57         NaN        0
# 58         NaN        0
# 59         NaN        0
# 60         NaN        0
# 61         NaN        0

# %%
gdp_data.query('countryiso3code == "ITA" & value > 23000')
# Out:
#                         indicator country countryiso3code  date         value  \
# 109  GDP per capita (current US$)   Italy             ITA  2024  40385.341396
# 110  GDP per capita (current US$)   Italy             ITA  2023  39277.083878
# 111  GDP per capita (current US$)   Italy             ITA  2022  35653.904210
# 112  GDP per capita (current US$)   Italy             ITA  2021  36852.542541
# 113  GDP per capita (current US$)   Italy             ITA  2020  32091.486662
# 114  GDP per capita (current US$)   Italy             ITA  2019  33812.788725
# 115  GDP per capita (current US$)   Italy             ITA  2018  34904.108192
# 116  GDP per capita (current US$)   Italy             ITA  2017  32844.115661
# 117  GDP per capita (current US$)   Italy             ITA  2016  31391.569290
# 118  GDP per capita (current US$)   Italy             ITA  2015  30639.882975
# 119  GDP per capita (current US$)   Italy             ITA  2014  36028.349402
# 120  GDP per capita (current US$)   Italy             ITA  2013  35701.674600
# 121  GDP per capita (current US$)   Italy             ITA  2012  34854.394944
# 122  GDP per capita (current US$)   Italy             ITA  2011  38432.374282
# 123  GDP per capita (current US$)   Italy             ITA  2010  35856.862549
# 124  GDP per capita (current US$)   Italy             ITA  2009  37099.613396
# 125  GDP per capita (current US$)   Italy             ITA  2008  40828.579558
# 126  GDP per capita (current US$)   Italy             ITA  2007  37826.175455
# 127  GDP per capita (current US$)   Italy             ITA  2006  33537.128699
# 128  GDP per capita (current US$)   Italy             ITA  2005  32062.723834
# 129  GDP per capita (current US$)   Italy             ITA  2004  31348.190184
# 130  GDP per capita (current US$)   Italy             ITA  2003  27577.570032
# 137  GDP per capita (current US$)   Italy             ITA  1996  23122.933722
# 141  GDP per capita (current US$)   Italy             ITA  1992  23297.046033
#
#      unit  obs_status  decimal
# 109   NaN         NaN        1
# 110   NaN         NaN        1
# 111   NaN         NaN        1
# 112   NaN         NaN        1
# 113   NaN         NaN        1
# 114   NaN         NaN        1
# 115   NaN         NaN        1
# 116   NaN         NaN        1
# 117   NaN         NaN        1
# 118   NaN         NaN        1
# 119   NaN         NaN        1
# 120   NaN         NaN        1
# 121   NaN         NaN        1
# 122   NaN         NaN        1
# 123   NaN         NaN        1
# 124   NaN         NaN        1
# 125   NaN         NaN        1
# 126   NaN         NaN        1
# 127   NaN         NaN        1
# 128   NaN         NaN        1
# 129   NaN         NaN        1
# 130   NaN         NaN        1
# 137   NaN         NaN        1
# 141   NaN         NaN        1

# %%
gdp_data.query('date == 2024 | date == 2023')
# Out:
#                         indicator  country countryiso3code  date  \
# 1    GDP per capita (current US$)  Germany             DEU  2024
# 2    GDP per capita (current US$)  Germany             DEU  2023
# 37   GDP per capita (current US$)    Spain             ESP  2024
# 38   GDP per capita (current US$)    Spain             ESP  2023
# 73   GDP per capita (current US$)   France             FRA  2024
# 74   GDP per capita (current US$)   France             FRA  2023
# 109  GDP per capita (current US$)    Italy             ITA  2024
# 110  GDP per capita (current US$)    Italy             ITA  2023
#
#             value  unit  obs_status  decimal
# 1    56103.732318   NaN         NaN        1
# 2    54776.766824   NaN         NaN        1
# 37   35326.768307   NaN         NaN        1
# 38   33493.222541   NaN         NaN        1
# 73   46103.084086   NaN         NaN        1
# 74   44700.138418   NaN         NaN        1
# 109  40385.341396   NaN         NaN        1
# 110  39277.083878   NaN         NaN        1

# %% [markdown]
# ## 2.4 Filter in a List
#
# Filter rows where column value is in a list.

# %%
# Filter Multiple and show unique countries
# You can either do one or two lines

pop_data.query("country in ['Spain', 'Italy']")
# Out:
#              indicator country countryiso3code  date       value  unit  \
# 36   Population, total   Spain             ESP  2025         NaN   NaN
# 37   Population, total   Spain             ESP  2024  48848840.0   NaN
# 38   Population, total   Spain             ESP  2023  48352528.0   NaN
# 39   Population, total   Spain             ESP  2022  47786102.0   NaN
# 40   Population, total   Spain             ESP  2021  47443821.0   NaN
# ..                 ...     ...             ...   ...         ...   ...
# 139  Population, total   Italy             ITA  1994  56843400.0   NaN
# 140  Population, total   Italy             ITA  1993  56831821.0   NaN
# 141  Population, total   Italy             ITA  1992  56797087.0   NaN
# 142  Population, total   Italy             ITA  1991  56758521.0   NaN
# 143  Population, total   Italy             ITA  1990  56719240.0   NaN
#
#      obs_status  decimal
# 36          NaN        0
# 37          NaN        0
# 38          NaN        0
# 39          NaN        0
# 40          NaN        0
# ..          ...      ...
# 139         NaN        0
# 140         NaN        0
# 141         NaN        0
# 142         NaN        0
# 143         NaN        0
#
# [72 rows x 8 columns]

# %% [markdown]
# ## 2.5 Select Rows and Columns
#
# Combine row filtering with column selection.

# %%
# Filter rows and select columns

# Filter rows and select columns

pop_data.query("country in ['Spain', 'Italy']")[['country', 'date', 'value']]
# Out:
#     country  date       value
# 36    Spain  2025         NaN
# 37    Spain  2024  48848840.0
# 38    Spain  2023  48352528.0
# 39    Spain  2022  47786102.0
# 40    Spain  2021  47443821.0
# ..      ...   ...         ...
# 139   Italy  1994  56843400.0
# 140   Italy  1993  56831821.0
# 141   Italy  1992  56797087.0
# 142   Italy  1991  56758521.0
# 143   Italy  1990  56719240.0
#
# [72 rows x 3 columns]

# %%
pop_data.query("country in ['Spain', 'Italy'] & date == 2024")[['country', 'date', 'value']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 pop_data.query("country in ['Spain', 'Italy']")[['country', 'date == 2024', 'value']]
#
# File c:\Users\marti\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\marti\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\marti\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['date == 2024'] not in index"

# %% [markdown]
# ## 2.6 Rename Columns
#
# Rename columns in the dataframe.

# %%
# Before rename
democracy_gdp.head(2)

# %%
# Rename using rename with axis parameter

#YOUR CODE HERE
