# %% [markdown]
# # Homework 2: Functions, Merging & Visualization
#
# This assignment synthesizes concepts from the Week 4 practice notebooks. Use the table below as a reference for where each function was introduced.
#
# ### **Concept Reference Map**
#
# | Category | Concept / Function | Original Reference Notebook |
# | :--- | :--- | :--- |
# | **Data Exploration** | `info()`, `columns`, `unique()`, `head()` | `1-visualization_basics.ipynb` |
# | **Statistics** | `describe()`, `mean()`, `pct_change()` | `1-visualization_basics.ipynb` |
# | **Manipulation** | `rename()`, `query()`, `drop()`, `set_index()` | `1-visualization_basics.ipynb` / `2-merging_practice.ipynb` |
# | **Aggregation** | `groupby()` | `1-visualization_basics.ipynb` |
# | **Time Series** | `pd.to_datetime()`, `PeriodIndex` | `2-merging_practice.ipynb` |
# | **Merging** | `pd.merge()`, `pd.concat()` | `2-merging_practice.ipynb` |
# | **Visualization** | `plot()`, `scatter()`, `barh()` | `1-visualization_basics.ipynb` |
#
# ---

# %% [markdown]
# ## A. Importing Data
#
# Run the cell below to load the WorldBank API function and download population and GDP data for G7 countries.

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt

def get_wb_data(indicator, countries_list, start_year, end_year):
    country_str = ';'.join(countries_list)
    url = f'https://api.worldbank.org/v2/country/{country_str}/indicator/{indicator}?date={start_year}:{end_year}&format=json&per_page=1000'
    response = requests.get(url)
    data = response.json()[1]
    df = pd.json_normalize(data)
    return df[['countryiso3code', 'date', 'value']]

# %% [markdown]
# ## A.1 Show info

# %%
# CREATE Country list of G7 countries using ISO3 Codes
# YOUR CODE HERE g7 =

# %%
g7 = ["CAN", "FRA", "DEU", "ITA", "JPN", "GBR", "USA"]
indicator = 'FP.CPI.TOTL.ZG'
start = 2000
end = 2022

# %%
url_g7 = 'https://api.worldbank.org/v2/country/{country_str}/indicator/{indicator}?date={start_year}:{end_year}&format=json&per_page=1000'
df_countries_list = g7
get_wb_data(indicator, g7, start, end)
# Out:
#     countryiso3code  date     value
# 0               CAN  2022  6.802801
# 1               CAN  2021  3.395193
# 2               CAN  2020  0.717000
# 3               CAN  2019  1.949269
# 4               CAN  2018  2.268226
# ..              ...   ...       ...
# 156             USA  2004  2.677237
# 157             USA  2003  2.270095
# 158             USA  2002  1.586032
# 159             USA  2001  2.826171
# 160             USA  2000  3.376857
#
# [161 rows x 3 columns]

# %% [markdown]
# ## A.2 Show column names

# %%
# YOUR CODE HERE
inflation_df = get_wb_data('FP.CPI.TOTL.ZG', g7, 2000, 2022)

# %% [markdown]
# ## A.3 Show unique countries

# %%
# YOUR CODE HERE
url_g7 = 'https://api.worldbank.org/v2/country/{country_str}/indicator/{indicator}?date={start_year}:{end_year}&format=json&per_page=1000'
df_countries_list = g7
get_wb_data(indicator, g7, start, end)
# Out:
#     countryiso3code  date     value
# 0               CAN  2022  6.802801
# 1               CAN  2021  3.395193
# 2               CAN  2020  0.717000
# 3               CAN  2019  1.949269
# 4               CAN  2018  2.268226
# ..              ...   ...       ...
# 156             USA  2004  2.677237
# 157             USA  2003  2.270095
# 158             USA  2002  1.586032
# 159             USA  2001  2.826171
# 160             USA  2000  3.376857
#
# [161 rows x 3 columns]

# %% [markdown]
# # 1. Show GDP Growth for Japan using above data

# %% [markdown]
# ## 1.A Rename column for country and value

# %%
inflation_df = get_wb_data(indicator, g7, start, end)

# %%
# Rename country and value columns
# YOUR CODE HERE
inflation_df.rename(columns={'countryiso3code' : 'country', 'value' : 'inflation'})
inflation_df.head(2)
# Out:
#   countryiso3code  date     value
# 0             CAN  2022  6.802801
# 1             CAN  2021  3.395193

# %%
inflation_df_final = inflation_df.rename(columns={'countryiso3code' : 'country', 'value' : 'inflation'})
inflation_df_final.head(2)
# Out:
#   country  date  inflation
# 0     CAN  2022   6.802801
# 1     CAN  2021   3.395193

# %% [markdown]
# ## 1.1 Create new data with only Japan

# %%
# Query japan
# YOUR CODE HERE
df_jp = inflation_df_final.query("country == 'JPN'")
df_jp.head(2)
# Out:
#     country  date  inflation
# 115     JPN  2022   2.497703
# 116     JPN  2021  -0.233353

# %% [markdown]
# ## 1.2 Set index as date, sort index, and drop country column

# %%
# Set index 
# YOUR CODE HERE
df_jp_final = df_jp.set_index("date")
df_jp_final.head(2)
# Out:
#      country  inflation
# date
# 2022     JPN   2.497703
# 2021     JPN  -0.233353

# %%
# DROP country column
# YOUR CODE HERE 
df_jp_finale2 = df_jp_final.drop(['country'], axis='columns')
df_jp_finale2.head(2)
# Out:
#       inflation
# date
# 2022   2.497703
# 2021  -0.233353

# %%
# Sort index makes it so date is descending
# YOUR CODE HERE 
df_jp_finale3 = df_jp_finale2.sort_index()
df_jp_finale3.head(2)
# Out:
#       inflation
# date
# 2000  -0.676579
# 2001  -0.740056

# %% [markdown]
# ## 1.3 Plot

# %%
# Your code here
df_jp_finale3.plot()
plt.title("Japan Inflation");

# %% [markdown]
# # 2. Merging Data
# ## 2.A Importing data

# %%
df_gdp = pd.read_csv(r"C:\Users\eye24\OneDrive\ドキュメント\GitHub\datascience-publicpolicy-2026\data\hw\eichengreen_1.csv")
df_gdp.head(2)
# Out:
#   economy  date country    gdp_pc_ppp       gdp_ppp  ir_spread  cred_priv_sec  \
# 0      BR  1997  Brunei  63095.776415  19683.232219        NaN            NaN
# 1      BR  1998  Brunei  62020.909406  19793.601111        NaN            NaN
#
#    bureaucracy_qual  corruption  investment_profile  law_order  exchange_rate  \
# 0          3.291667    4.000000            9.750000        6.0       0.020075
# 1          3.000000    3.583333            7.583333        6.0       0.039924
#
#    sd_interbank
# 0           NaN
# 1           NaN

# %%
df_govt_bond = pd.read_csv(r"C:\Users\eye24\OneDrive\ドキュメント\GitHub\datascience-publicpolicy-2026\data\hw\eichengreen_2.csv")
df_govt_bond.head(2)
# Out:
#   economy  date country  net_borrow  kai  kao  bank_con  legor_uk     dist_eq  \
# 0      BR  1997  Brunei      11.062  0.1  0.0       NaN       NaN  500.529999
# 1      BR  1998  Brunei      14.424  0.1  0.0       NaN       NaN  500.529999
#
#    bond_market_cap  bo_plbn_scaled  bo_siln_scaled  bo_pabr_scaled  \
# 0              NaN             NaN             NaN             NaN
# 1              NaN             NaN             NaN             NaN
#
#    bo_siar_scaled
# 0             NaN
# 1             NaN

# %% [markdown]
# ## 2.1 Filter one country

# %%
df_govt_bond.economy.unique()
# Out:
# array(['BR', 'CN', 'HK', 'ID', 'JP', 'KH', 'KR', 'LA', 'MM', 'MY', 'PH',
#        'SG', 'TH', 'VN'], dtype=object)

# %%
#MAKE SURE YOU query df_govt_bond
#YOUR CODE HERE query VN
df_govt_bond_vn = df_govt_bond.query("economy == 'VN'")
df_govt_bond_vn.head(2)
# Out:
#     economy  date  country  net_borrow       kai       kao  bank_con  \
# 299      VN  1997  Vietnam         NaN  1.000000  0.714286  84.50824
# 300      VN  1998  Vietnam         NaN  0.888889  1.000000  84.61529
#
#      legor_uk      dist_eq  bond_market_cap  bo_plbn_scaled  bo_siln_scaled  \
# 299       0.0  2338.550049              NaN             NaN             NaN
# 300       0.0  2338.550049              NaN             NaN             NaN
#
#      bo_pabr_scaled  bo_siar_scaled
# 299             NaN             NaN
# 300             NaN             NaN

# %%
#MAKE SURE YOU GET GDP Data df_gdp
#YOUR CODE HERE query VN 
df_gdp_vn = df_gdp.query("economy == 'VN'")
df_gdp_vn.head(2)
# Out:
#     economy  date  country   gdp_pc_ppp        gdp_ppp  ir_spread  \
# 299      VN  1997  Vietnam  1709.896773  131889.833685   5.904167
# 300      VN  1998  Vietnam  1805.815779  141062.581723   5.170000
#
#      cred_priv_sec  bureaucracy_qual  corruption  investment_profile  \
# 299      19.848841               2.0    2.416667            6.583333
# 300      20.123863               2.0    2.000000            5.166667
#
#      law_order  exchange_rate  sd_interbank
# 299        5.0       0.013462           NaN
# 300        5.0       0.024974           NaN

# %% [markdown]
# ## 2.2 Filter gdp_pc_pp and set date as index

# %%
# YOUR CODE HERE
columns = ['date' , 'gdp_pc_ppp']
df_gdp_vn_gdp_pc_ppp = df_gdp_vn[columns]
df_gdp_vn_gdp_pc_ppp_final = df_gdp_vn_gdp_pc_ppp.set_index("date")
df_gdp_vn_gdp_pc_ppp_final.head(2)
# Out:
#        gdp_pc_ppp
# date
# 1997  1709.896773
# 1998  1805.815779

# %%
# YOUR CODE HERE
columns = ['date' , 'net_borrow']
df_govt_bond_vn_net_borrow = df_govt_bond_vn[columns]
df_govt_bond_vn_net_borrow_final = df_govt_bond_vn_net_borrow.set_index("date")
df_govt_bond_vn_net_borrow_final.head(2)
# Out:
#       net_borrow
# date
# 1997         NaN
# 1998         NaN

# %%
df_govt_bond_vn_net_borrow_final_indexed = df_govt_bond_vn_net_borrow_final.dropna().sort_index()

# %% [markdown]
# ## 2.3 Merge data

# %%
# NOTE I sorted index and drop na

# YOUR CODE HERE

def merge_data(df_gdp_vn_gdp_pc_ppp_final , df_govt_bond_vn_net_borrow_final_indexed):
   
    df_merge = pd.merge(
        df_gdp_vn_gdp_pc_ppp_final , 
        df_govt_bond_vn_net_borrow_final_indexed,
        right_index=True,
        left_index=True,
        how='inner'
    )
    return df_merge

df_merge = merge_data(df_gdp_vn_gdp_pc_ppp_final , df_govt_bond_vn_net_borrow_final_indexed)
df_merge.head(2)
# Out:
#        gdp_pc_ppp  net_borrow
# date
# 1999  1896.989470       0.126
# 2000  2048.363759       1.582

# %% [markdown]
# ## 2.4 Convert to datetime

# %%
# No code changes needed
df_merge.index = pd.to_datetime(df_merge.index, format = "%Y")
df_merge.head(2)
# Out:
#              gdp_pc_ppp  net_borrow
# date
# 1999-01-01  1896.989470       0.126
# 2000-01-01  2048.363759       1.582

# %% [markdown]
# ## 2.4 Plot net_borrow

# %%
# Your code here
df_govt_bond_vn_net_borrow_final_indexed.plot()
plt.title("Net Borrowing (% GDP)")
plt.ylabel("% GDP")
# Out:
# Text(0, 0.5, '% GDP')

# %% [markdown]
# # 3. Functions

# %% [markdown]
# ## 3.A Import Data

# %%
df_gdp = pd.read_csv(r"C:\Users\eye24\OneDrive\ドキュメント\GitHub\datascience-publicpolicy-2026\data\hw\eichengreen_1.csv")
df_govt_bond = pd.read_csv(r"C:\Users\eye24\OneDrive\ドキュメント\GitHub\datascience-publicpolicy-2026\data\hw\eichengreen_2.csv")
df_merge_all = pd.concat([df_gdp, df_govt_bond], axis = 'columns')
df_merge_all.columns
# Out:
# Index(['economy', 'date', 'country', 'gdp_pc_ppp', 'gdp_ppp', 'ir_spread',
#        'cred_priv_sec', 'bureaucracy_qual', 'corruption', 'investment_profile',
#        'law_order', 'exchange_rate', 'sd_interbank', 'economy', 'date',
#        'country', 'net_borrow', 'kai', 'kao', 'bank_con', 'legor_uk',
#        'dist_eq', 'bond_market_cap', 'bo_plbn_scaled', 'bo_siln_scaled',
#        'bo_pabr_scaled', 'bo_siar_scaled'],
#       dtype='object')

# %%
df_merge_all = pd.merge(df_gdp, df_govt_bond, on=['economy', 'date', 'country'])
df_merge_all.columns
# Out:
# Index(['economy', 'date', 'country', 'gdp_pc_ppp', 'gdp_ppp', 'ir_spread',
#        'cred_priv_sec', 'bureaucracy_qual', 'corruption', 'investment_profile',
#        'law_order', 'exchange_rate', 'sd_interbank', 'net_borrow', 'kai',
#        'kao', 'bank_con', 'legor_uk', 'dist_eq', 'bond_market_cap',
#        'bo_plbn_scaled', 'bo_siln_scaled', 'bo_pabr_scaled', 'bo_siar_scaled'],
#       dtype='object')

# %% [markdown]
# ## 3.1 Create function to conver to datetime

# %%
def convert_date(df_merge_all):
    df_merge_all['date'] = pd.PeriodIndex(df_merge_all['date'], freq='Q').to_timestamp()
    df_merge_all['date'] = pd.to_datetime(df_merge_all['date'], format='%Y')
    #Your code here
    #Your code here
    #Use as many lines as you want
    return df_merge_all

# %%
df_merge_all.head(1)
# Out:
#   economy  date country    gdp_pc_ppp       gdp_ppp  ir_spread  cred_priv_sec  \
# 0      BR  1997  Brunei  63095.776415  19683.232219        NaN            NaN
#
#    bureaucracy_qual  corruption  investment_profile  ...  kai  kao  bank_con  \
# 0          3.291667         4.0                9.75  ...  0.1  0.0       NaN
#
#    legor_uk     dist_eq  bond_market_cap  bo_plbn_scaled  bo_siln_scaled  \
# 0       NaN  500.529999              NaN             NaN             NaN
#
#    bo_pabr_scaled  bo_siar_scaled
# 0             NaN             NaN
#
# [1 rows x 24 columns]

# %%
df_merge_all_converted = convert_date(df_merge_all)
df_merge_all_converted.head(1)
# Out:
#   economy       date country    gdp_pc_ppp       gdp_ppp  ir_spread  \
# 0      BR 1997-01-01  Brunei  63095.776415  19683.232219        NaN
#
#    cred_priv_sec  bureaucracy_qual  corruption  investment_profile  ...  kai  \
# 0            NaN          3.291667         4.0                9.75  ...  0.1
#
#    kao  bank_con  legor_uk     dist_eq  bond_market_cap  bo_plbn_scaled  \
# 0  0.0       NaN       NaN  500.529999              NaN             NaN
#
#    bo_siln_scaled  bo_pabr_scaled  bo_siar_scaled
# 0             NaN             NaN             NaN
#
# [1 rows x 24 columns]

# %% [markdown]
# ## 3.2 Rename column function

# %%
def plot_scatter(x_title, y_title, main_title):
    df_plot = df_merge_all_converted
    
    # Define the columns for x and y

    plt.scatter(df_plot['gdp_pc_ppp'].pct_change(1), df_plot['net_borrow'])
    plt.xlabel('GDP per Capita (PPP)')
    plt.ylabel('Net Borrowing')
    plt.title('Higher Government Borrowing Corrleated With Faster GDP Growth')
    plt.xlim(-0.10, 0.15) 
    # Set labels and title
    # Your code here
    # Your code here
    # Your code here

# Note corrleation does not equal causation :)
plot_scatter('GDP per Capita (PPP)', 'Net Borrowing', 'Higher Government Borrowing Corrleated With Faster GDP Growth')
# Out:
# C:\Users\eye24\AppData\Local\Temp\ipykernel_9324\2631136393.py:6: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   plt.scatter(df_plot['gdp_pc_ppp'].pct_change(1), df_plot['net_borrow'])
