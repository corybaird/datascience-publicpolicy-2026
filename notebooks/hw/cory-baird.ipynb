# %% [markdown]
# # Homework 1: Data Reading & Manipulation
#
# In this homework, you will practice:
# 1. Reading data from CSV files and APIs
# 2. Data manipulation techniques covered in Week 2

# %% [markdown]
# # Section 1: Reading Data

# %% [markdown]
# ## 1.1 Reading CSV Files
#
# ##### IMPORTANT: We will read data from the `data/hw/` folder so you need to remember to go back two folders to access data

# %%
#IMPORT PANDAS TOOLS
import pandas as pd

# More changes

# %% [markdown]
# ### 1.1.1 GDP and Democracy Data
#
# Load the `democracy_gdp.csv` file.

# %%
democracy_gdp = pd.read_csv("/Users/hannahwu/Documents/GitHub/datascience-publicpolicy-2026/data/hw/hw_3/data_gpr_daily_recent.csv")
democracy_gdp.head(4)
# Out:
#         DAY  N10D    GPRD GPRD_ACT  GPRD_THREAT      date  GPRD_MA30  \
# 0  19850101   216  230.04   275.20       153.03  1/1/1985     230.04
# 1  19850102   315  115.68   146.77        87.44  1/2/1985     172.86
# 2  19850103   374   97.43   158.94        29.46  1/3/1985     147.71
# 3  19850104   421  157.37   156.88       157.03  1/4/1985     150.13
#
#    GPRD_MA7 event  var_name                                         var_label
# 0    230.04   NaN       DAY                                               DAY
# 1    172.86   NaN      N10D  Number of articles (10 recent newspapers, 1985-)
# 2    147.71   NaN      GPRD                  Daily GPR (Index: 1985:2019=100)
# 3    150.13   NaN  GPRD_ACT             Daily GPR Acts (Index: 1985:2019=100)

# %% [markdown]
# ### 1.1.2 Green house gas (GHG) Emissions Data
#
# Load the `ghg.csv` file.

# %%
ghg_file_path = "/Users/hannahwu/Documents/GitHub/datascience-publicpolicy-2026/data/hw/ghg.csv"
ghg = pd.read_csv(ghg_file_path)
ghg.tail(3)
# Out:
#             Country  year     emissions
# 11445  GLOBAL TOTAL  2021  51568.250032
# 11446  GLOBAL TOTAL  2022  51968.471601
# 11447  GLOBAL TOTAL  2023  52962.900859

# %% [markdown]
# ## 1.2 Reading Data from an API
#
# YOU MUST RUN THE NEXT CELL TO DOWNLOAD GDP AND POPULATION DATA

# %%
import requests
import io

def download_worldbank(indicator, countries, date_start, date_end):
    url_base = 'https://api.worldbank.org/v2/'
    country_codes = ';'.join(countries)
    url = f'{url_base}country/{country_codes}/indicator/{indicator}?date={date_start}:{date_end}&per_page=30000'
    response = requests.get(url)
    df = pd.read_xml(io.BytesIO(response.content))
    return df

# %% [markdown]
# ### 1.2.1 Download GDP Data (1990-2026)
#
# Download GDP per capita data for a different set of countries than those in the CSV files.

# %%
gdp_data = download_worldbank(
    indicator='NY.GDP.PCAP.CD',
    date_start= 1990,
    date_end= 2026,
    countries= ['USA', 'CAN', 'MEX', 'GBR', 'FRA', 'DEU', 'JPN', 'AUS']
)
gdp_data.head(2)
# Out:
#                       indicator    country countryiso3code  date  \
# 0  GDP per capita (current US$)  Australia             AUS  2025
# 1  GDP per capita (current US$)  Australia             AUS  2024
#
#           value  unit  obs_status  decimal
# 0           NaN   NaN         NaN        1
# 1  64603.985631   NaN         NaN        1

# %% [markdown]
# ### 1.2.2 Download Population Data (1990-2026)
#
# Download population data for the same countries.

# %%
population_indicator = "SP.POP.TOTL"



country_list = [
    "USA",  # United States of America
    "CAN",  # Canada
    "MEX",  # Mexico
    "GBR",  # United Kingdom of Great Britain and Northern Ireland
    "FRA",  # France
    "DEU",  # Germany (Deutschland)
    "JPN",  # Japan
    "AUS"   # Australia
]

pop_data = download_worldbank(
    indicator=population_indicator,
    countries=country_list,
    date_start=1990,
    date_end=2026
)
pop_data.tail(3)
# Out:
#              indicator        country countryiso3code  date        value  \
# 285  Population, total  United States             USA  1992  256514000.0
# 286  Population, total  United States             USA  1991  252981000.0
# 287  Population, total  United States             USA  1990  249623000.0
#
#      unit  obs_status  decimal
# 285   NaN         NaN        0
# 286   NaN         NaN        0
# 287   NaN         NaN        0

# %% [markdown]
# # Section 2: Data Manipulation
#
# Now let's practice the data manipulation techniques from Week 2.

# %% [markdown]
# ## 2.1 Select Columns
#
# Select specific columns from the democracy_gdp dataset.

# %%
gdp_data["country"].head(5)
# Out:
# 0    Australia
# 1    Australia
# 2    Australia
# 3    Australia
# 4    Australia
# Name: country, dtype: object

# %% [markdown]
# ## 2.2 Filter Rows
#
# Filter rows based on conditions.

# %%
# Show unique values in a column
gdp_data["country"].unique()
# Out:
# array(['Australia', 'Canada', 'Germany', 'France', 'United Kingdom',
#        'Japan', 'Mexico', 'United States'], dtype=object)

# %%
# Filter using query

gdp_data.query('country == "Japan"').head(3)
# Out:
#                         indicator country countryiso3code  date         value  \
# 180  GDP per capita (current US$)   Japan             JPN  2025           NaN
# 181  GDP per capita (current US$)   Japan             JPN  2024  32487.077805
# 182  GDP per capita (current US$)   Japan             JPN  2023  33836.175627
#
#      unit  obs_status  decimal
# 180   NaN         NaN        1
# 181   NaN         NaN        1
# 182   NaN         NaN        1

# %% [markdown]
# ## 2.3 Multiple Conditions
#
# Filter using multiple conditions.

# %%
# Filter with multiple conditions

#YOUR CODE HERE
gdp_data.query('country == "Japan" & date == 2024')
# Out:
#                         indicator country countryiso3code  date         value  \
# 181  GDP per capita (current US$)   Japan             JPN  2024  32487.077805
#
#      unit  obs_status  decimal
# 181   NaN         NaN        1

# %% [markdown]
# ## 2.4 Filter in a List
#
# Filter rows where column value is in a list.

# %%
# Filter Multiple and show unique countries
# You can either do one or two lines

gdp_data.query('country in ["Japan", "USA"]').head(3)
#YOUR CODE HERE
# Out:
#                         indicator country countryiso3code  date         value  \
# 180  GDP per capita (current US$)   Japan             JPN  2025           NaN
# 181  GDP per capita (current US$)   Japan             JPN  2024  32487.077805
# 182  GDP per capita (current US$)   Japan             JPN  2023  33836.175627
#
#      unit  obs_status  decimal
# 180   NaN         NaN        1
# 181   NaN         NaN        1
# 182   NaN         NaN        1

# %% [markdown]
# ## 2.5 Select Rows and Columns
#
# Combine row filtering with column selection.

# %%
# Filter rows and select columns
gdp_data.query('country == "Japan"')[['country','date','value','indicator']].tail(3)
#YOUR CODE HERE
# Out:
#     country  date         value                     indicator
# 213   Japan  1992  31992.790212  GDP per capita (current US$)
# 214   Japan  1991  29428.428904  GDP per capita (current US$)
# 215   Japan  1990  25801.395039  GDP per capita (current US$)

# %% [markdown]
# ## 2.6 Rename Columns
#
# Rename columns in the dataframe.

# %%
# Before rename
democracy_gdp.head(2)
# Out:
#         DAY  N10D    GPRD GPRD_ACT  GPRD_THREAT      date  GPRD_MA30  \
# 0  19850101   216  230.04   275.20       153.03  1/1/1985     230.04
# 1  19850102   315  115.68   146.77        87.44  1/2/1985     172.86
#
#    GPRD_MA7 event var_name                                         var_label
# 0    230.04   NaN      DAY                                               DAY
# 1    172.86   NaN     N10D  Number of articles (10 recent newspapers, 1985-)

# %%
# Rename using rename with axis parameter
gdp_data.rename({'value': 'GDP'}, axis=1)
gdp_data.head(2)
#YOUR CODE HERE
# Out:
#                       indicator    country countryiso3code  date  \
# 0  GDP per capita (current US$)  Australia             AUS  2025
# 1  GDP per capita (current US$)  Australia             AUS  2024
#
#             GDP  unit  obs_status  decimal
# 0           NaN   NaN         NaN        1
# 1  64603.985631   NaN         NaN        1
