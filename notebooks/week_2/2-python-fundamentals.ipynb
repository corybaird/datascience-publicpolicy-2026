# %% [markdown]
# # Python Fundamentals & Pandas Basics
# This notebook covers the basic Python syntax and an introduction to the pandas library.

# %% [markdown]
# # A. Looking Under the Hood
#
# In Notebook 1 you successfully imported local data, pulled data from GitHub, and even Queried a World Bank API! You used strings, lists, and variables to do it. Now, we are going to look under the hood at the exact 'grammar' of what you just built.

# %% [markdown]
# ## A. Note for R-users
#
# - Python is in many ways similiar to R
#
# - Comment code: #
# - Some functions are exactly the same: print()
# - Saving an object requires you to write a name and set it equal to whatever object you are interested in saving
# - You must run the code in the correct order
# - We use libraries!

# %%
# REMEMBER THIS IS WHAT WE USED BEFORE
# This line saves the web address (URL) of the World Bank data file as text in a variable named 'url'.
url = "https://github.com/Data-Science-Public-Policy/graspp_2025_spring/raw/refs/heads/module_1/data/examples/module_1/world_bank_data.csv"

# %%
# This is a comment
print('This is a print function')
# Out:
# This is a print function

# %%
saved_object = 'hello world'
print(saved_object)
# Out:
# hello world

# %%
saved_object = 'GRASPP IS COOL'
saved_object
# Out:
# 'GRASPP IS COOL'

# %% [markdown]
# ## A.1 Strings
#
# - Think of it as a piece data that has quotes
# - R-users: This is the same as in R!

# %%
my_str = 'Python is cool'
print(my_str)
# Out:
# Python is cool

# %% [markdown]
# ### A.1.1 This function can tell us what type our object is

# %%
type(my_str)
# Out:
# str

# %% [markdown]
# ### A.1.2 Overwriting

# %%
my_str = 'Python is NOT cool'
my_str
# Out:
# 'Python is NOT cool'

# %% [markdown]
# ## A.2 Integers/Float

# %%
my_num = 100
type(my_num)
# Out:
# int

# %%
my_num = 100.9483859390942949
type(my_num)
# Out:
# float

# %% [markdown]
# ## A.3 Dictionaries

# %%
rename_country_map = {
    "Canada": "Canada",
    "Mexico": "United Mexican States",
    "United States": "United States of America",
    "Germany": "Federal Republic of Germany",
}

# %%
rename_country_map.values()
# Out:
# dict_values(['Canada', 'United Mexican States', 'United States of America', 'Federal Republic of Germany'])

# %%
rename_country_map.keys()
# Out:
# dict_keys(['Canada', 'Mexico', 'United States', 'Germany'])

# %% [markdown]
# # B. Introduction to Pandas
#
# ### For R users: Pandas is similar to DPLYR!
#
# In general we use it to:
#
# - Manipulate data (Today's topic)
# - Viusualize our data (graphing etc.)
# - Download data directly from the internet
# - Build models (Regression, Machine learning, Neural Networks)

# %% [markdown]
# ## B.A We must import the library before using!
# - Again this is similar to R
# - However unlike R: in order to use the functions (in general) we have to use an acronym to access the functions

# %%
import pandas as pd

# %% [markdown]
# ## B.1 Import data
# - pd.read_stata
# - pd.read_csv
# - pd.read_excel

# %%
url = "https://raw.githubusercontent.com/corybaird/datascience-publicpolicy-2026/refs/heads/main/data/examples/week_2/world_bank_data.csv"
df = pd.read_csv(url)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## B.3 Select and Filter

# %% [markdown]
# ### B.3.1 Select column

# %%
df['country']
# Out:
# 0            Canada
# 1            Canada
# 2            Canada
# 3             Japan
# 4             Japan
# 5             Japan
# 6            Mexico
# 7            Mexico
# 8            Mexico
# 9     United States
# 10    United States
# 11    United States
# Name: country, dtype: object

# %%
df['countryiso3code']
# Out:
# 0     CAN
# 1     CAN
# 2     CAN
# 3     JPN
# 4     JPN
# 5     JPN
# 6     MEX
# 7     MEX
# 8     MEX
# 9     USA
# 10    USA
# 11    USA
# Name: countryiso3code, dtype: object

# %%
df['country'].head(2)
# Out:
# 0    Canada
# 1    Canada
# Name: country, dtype: object

# %%
df.country.head(2)
# Out:
# 0    Canada
# 1    Canada
# Name: country, dtype: object

# %%
df.indicator
# Out:
# 0     GDP per capita (current US$)
# 1     GDP per capita (current US$)
# 2     GDP per capita (current US$)
# 3     GDP per capita (current US$)
# 4     GDP per capita (current US$)
# 5     GDP per capita (current US$)
# 6     GDP per capita (current US$)
# 7     GDP per capita (current US$)
# 8     GDP per capita (current US$)
# 9     GDP per capita (current US$)
# 10    GDP per capita (current US$)
# 11    GDP per capita (current US$)
# Name: indicator, dtype: object

# %% [markdown]
# ## B.3.2 Subset Rows
#
# <img src="Screenshots/subset_row.svg" />

# %% [markdown]
# ### B.3.2.1 Show unique values in a column

# %%
df.country.unique()
# Out:
# array(['Canada', 'Japan', 'Mexico', 'United States'], dtype=object)

# %%
df.indicator.unique()
# Out:
# array(['GDP per capita (current US$)'], dtype=object)

# %%
df.date.unique()
# Out:
# array([2023, 2022, 2021])

# %% [markdown]
# #### B.3.2.2 Select Row

# %%
df.query("country == 'Japan'")
# Out:
#    Unnamed: 0                     indicator country countryiso3code  date  \
# 3           3  GDP per capita (current US$)   Japan             JPN  2023
# 4           4  GDP per capita (current US$)   Japan             JPN  2022
# 5           5  GDP per capita (current US$)   Japan             JPN  2021
#
#           value
# 3  33766.526825
# 4  34017.271808
# 5  40058.537328

# %%
df.query("countryiso3code == 'MEX'")
# Out:
#    Unnamed: 0                     indicator country countryiso3code  date  \
# 6           6  GDP per capita (current US$)  Mexico             MEX  2023
# 7           7  GDP per capita (current US$)  Mexico             MEX  2022
# 8           8  GDP per capita (current US$)  Mexico             MEX  2021
#
#           value
# 6  13790.024343
# 7  11385.407076
# 8  10314.050674

# %%
mask = df.country == 'Japan'
mask[:2]
# Out:
# 0    False
# 1    False
# Name: country, dtype: bool

# %%
df[mask]
df.loc[mask]
# Out:
#    Unnamed: 0                     indicator country countryiso3code  date  \
# 3           3  GDP per capita (current US$)   Japan             JPN  2023
# 4           4  GDP per capita (current US$)   Japan             JPN  2022
# 5           5  GDP per capita (current US$)   Japan             JPN  2021
#
#           value
# 3  33766.526825
# 4  34017.271808
# 5  40058.537328

# %% [markdown]
# #### B.2.2.3 Subset multiple conditions

# %%
df.query("country == 'Japan' & date>2021")
# Out:
#    Unnamed: 0                     indicator country countryiso3code  date  \
# 3           3  GDP per capita (current US$)   Japan             JPN  2023
# 4           4  GDP per capita (current US$)   Japan             JPN  2022
#
#           value
# 3  33766.526825
# 4  34017.271808

# %% [markdown]
# #### B.3.2.4 Subset in a list

# %%
df.query("country in ['Japan', 'Mexico']")
# Out:
#    Unnamed: 0                     indicator country countryiso3code  date  \
# 3           3  GDP per capita (current US$)   Japan             JPN  2023
# 4           4  GDP per capita (current US$)   Japan             JPN  2022
# 5           5  GDP per capita (current US$)   Japan             JPN  2021
# 6           6  GDP per capita (current US$)  Mexico             MEX  2023
# 7           7  GDP per capita (current US$)  Mexico             MEX  2022
# 8           8  GDP per capita (current US$)  Mexico             MEX  2021
#
#           value
# 3  33766.526825
# 4  34017.271808
# 5  40058.537328
# 6  13790.024343
# 7  11385.407076
# 8  10314.050674

# %% [markdown]
# ### B.3.2.5 Subset rows and columns

# %%
df.query("country in ['Japan', 'Mexico']")[['country', 'date']]
# Out:
#   country  date
# 3   Japan  2023
# 4   Japan  2022
# 5   Japan  2021
# 6  Mexico  2023
# 7  Mexico  2022
# 8  Mexico  2021

# %%
df.query("countryiso3code in ['JPN', 'MEX']")[['country', 'date']]
# Out:
#   country  date
# 3   Japan  2023
# 4   Japan  2022
# 5   Japan  2021
# 6  Mexico  2023
# 7  Mexico  2022
# 8  Mexico  2021

# %% [markdown]
# ## B.3 Rename
#
# ### B.3.1 Rename columns

# %%
df.rename({"value" : "GDP"}, axis=1).head(2)
# Out:
#    Unnamed: 0                     indicator country countryiso3code  date  \
# 0           0  GDP per capita (current US$)  Canada             CAN  2023
# 1           1  GDP per capita (current US$)  Canada             CAN  2022
#
#             GDP
# 0  53431.185706
# 1  55509.393176

# %%
df.rename({"country": "pais", "countryiso3code": "codigo de pais", "date": "fecha"}, axis=1)
# Out:
#     Unnamed: 0                     indicator           pais codigo de pais  \
# 0            0  GDP per capita (current US$)         Canada            CAN
# 1            1  GDP per capita (current US$)         Canada            CAN
# 2            2  GDP per capita (current US$)         Canada            CAN
# 3            3  GDP per capita (current US$)          Japan            JPN
# 4            4  GDP per capita (current US$)          Japan            JPN
# 5            5  GDP per capita (current US$)          Japan            JPN
# 6            6  GDP per capita (current US$)         Mexico            MEX
# 7            7  GDP per capita (current US$)         Mexico            MEX
# 8            8  GDP per capita (current US$)         Mexico            MEX
# 9            9  GDP per capita (current US$)  United States            USA
# 10          10  GDP per capita (current US$)  United States            USA
# 11          11  GDP per capita (current US$)  United States            USA
#
#     fecha         value
# 0    2023  53431.185706
# 1    2022  55509.393176
# 2    2021  52496.844169
# 3    2023  33766.526825
# 4    2022  34017.271808
# 5    2021  40058.537328
# 6    2023  13790.024343
# 7    2022  11385.407076
# 8    2021  10314.050674
# 9    2023  82769.412211
# 10   2022  78035.175360
# 11   2021  71318.307359

# %% [markdown]
# ### B.3.2 Rename rows

# %%
rename_country_map = {
    "Canada" : "O CANANDA"
}
df.country.replace(rename_country_map)
# Out:
# 0         O CANANDA
# 1         O CANANDA
# 2         O CANANDA
# 3             Japan
# 4             Japan
# 5             Japan
# 6            Mexico
# 7            Mexico
# 8            Mexico
# 9     United States
# 10    United States
# 11    United States
# Name: country, dtype: object

# %%
df.country.map(rename_country_map)
# Out:
# 0     O CANANDA
# 1     O CANANDA
# 2     O CANANDA
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# Name: country, dtype: object

# %%
df.country.replace({"Mexico": "VIVA MEXICO"})
# Out:
# 0            Canada
# 1            Canada
# 2            Canada
# 3             Japan
# 4             Japan
# 5             Japan
# 6       VIVA MEXICO
# 7       VIVA MEXICO
# 8       VIVA MEXICO
# 9     United States
# 10    United States
# 11    United States
# Name: country, dtype: object

# %%
df = df.replace({"Mexico": "VIVA MEXICO"})
df
# Out:
# 0            Canada
# 1            Canada
# 2            Canada
# 3             Japan
# 4             Japan
# 5             Japan
# 6       VIVA MEXICO
# 7       VIVA MEXICO
# 8       VIVA MEXICO
# 9     United States
# 10    United States
# 11    United States
# Name: country, dtype: object

# %% [markdown]
# ## B.4 Apply functions to pandas

# %% [markdown]
# ### B.4.1 Basics

# %%
def basics(data):
    print('Head')
    print(data.head(2))
    print('')
    print('Tail')
    print(data.tail(2))
    print('')
    print('Columns')
    print(data.columns[:3])
    print('')
    print('Info')
    print(data.info())

basics(df)
# Out:
# Head
# 0    Canada
# 1    Canada
# Name: country, dtype: object
#
# Tail
# 10    United States
# 11    United States
# Name: country, dtype: object
#
# Columns
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16628\627766660.py in ?()
#      10     print('')
#      11     print('Info')
#      12     print(data.info())
#      13
# ---> 14 basics(df)
#
# ~\AppData\Local\Temp\ipykernel_16628\627766660.py in ?(data)
#       5     print('Tail')
#       6     print(data.tail(2))
#       7     print('')
#       8     print('Columns')
# ----> 9     print(data.columns[:3])
#      10     print('')
#      11     print('Info')
#      12     print(data.info())
#
# c:\Users\marti\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %% [markdown]
# ### B.4.2 subset

# %%
def subset(countries, columns):
    out = df.query(f"country in {countries}")[columns]
    return out
subset(
    countries = ['Japan', 'Mexico'],
    columns = ['country', 'date']
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16628\1940581881.py in ?()
#       1 def subset(countries, columns):
#       2     out = df.query(f"country in {countries}")[columns]
#       3     return out
# ----> 4 subset(
#       5     countries = ['Japan', 'Mexico'],
#       6     columns = ['country', 'date']
#       7 )
#
# ~\AppData\Local\Temp\ipykernel_16628\1940581881.py in ?(countries, columns)
#       1 def subset(countries, columns):
# ----> 2     out = df.query(f"country in {countries}")[columns]
#       3     return out
#
# c:\Users\marti\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'query'
